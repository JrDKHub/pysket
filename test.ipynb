# %%
import pandas as pd

data = pd.read_csv("src\\assets\\data.csv")
data
# Out:
#     Rk                    Team   Age   W   L  PW  PL    MOV   SOS    SRS  ...  \
# 0    1          Boston Celtics  28.2  64  18  66  16  11.34 -0.60  10.75  ...
# 1    2   Oklahoma City Thunder  23.4  57  25  58  24   7.41 -0.05   7.36  ...
# 2    3  Minnesota Timberwolves  27.2  56  26  57  25   6.45 -0.07   6.39  ...
# 3    4          Denver Nuggets  27.1  57  25  54  28   5.26 -0.03   5.23  ...
# 4    5         New York Knicks  26.4  50  32  53  29   4.59 -0.23   4.36  ...
# 5    6    New Orleans Pelicans  26.0  49  33  52  30   4.41  0.05   4.46  ...
# 6    7    Los Angeles Clippers  30.4  51  31  49  33   3.28  0.13   3.41  ...
# 7    8      Philadelphia 76ers  28.4  47  35  49  33   3.05 -0.54   2.51  ...
# 8    9            Phoenix Suns  29.3  49  33  49  33   3.06  0.02   3.08  ...
# 9   10          Indiana Pacers  25.3  47  35  48  34   3.05 -0.30   2.75  ...
# 10  11   Golden State Warriors  28.4  46  36  47  35   2.61  0.16   2.77  ...
# ...

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

df = pd.DataFrame(mydataset)
df
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
df["cars"] # df.cars
# Out:
# 0      BMW
# 1    Volvo
# 2     Ford
# Name: cars, dtype: object

# %%
df[['cars','passings']]
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
df.loc[0]
# Out:
# cars        BMW
# passings      3
# Name: 0, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
